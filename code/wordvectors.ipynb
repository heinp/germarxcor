# %%
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
# get single author's texts
with open("../txt/marx_engels/marx_engels_total.txt") as f:
    me_total = f.read()
with open("../txt/trotzki/trotzki_total.txt") as f:
    trotzki_total = f.read()
with open("../txt/stalin/stalin_total.txt") as f:
    stalin_total = f.read()

# %%
# get whole corpus
with open("../txt/all.txt") as f:
    all_total = f.read()

# %%
def prepare(text):
    sents = sent_tokenize(text)
    words = [word_tokenize(sent) for sent in sents]
    return words

# %%
# prepare single author's texts
me_prepared = prepare(me_total)
trotzki_prepared = prepare(trotzki_total)
stalin_prepared = prepare(stalin_total)

# %%
# prepare whole corpus
all_prepared = prepare(all_total)

# %%
# get reference corpus
with open("german-amazon-reviews.txt", encoding="iso-8859-15") as f:
    amazon = f.read()
amazon_prepared = prepare(amazon)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-38199921c296> in <module>()
#       1 # get reference corpus
# ----> 2 with open("german-amazon-reviews.txt", encoding="iso-8859-15") as f:
#       3     amazon = f.read()
#       4 amazon_prepared = prepare(amazon)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'german-amazon-reviews.txt'

# %%
# build model for whole corpus
model_all = Word2Vec(all_prepared, size=300)

# %%
# get analogies
model_all.wv.most_similar(positive=["Junge", "Frau"], negative=["Mann"], topn=100)
# Out:
# [('Perrier', 0.6235110759735107),
#  ('Stuart', 0.6121819019317627),
#  ('Staatsprokurator', 0.6116944551467896),
#  ('gläubige', 0.608957052230835),
#  ('Krummacher', 0.6083165407180786),
#  ('Thompson', 0.6060768365859985),
#  ('Madame', 0.6056742072105408),
#  ('Fould', 0.6023613810539246),
#  ('Clément', 0.6016688942909241),
#  ('Tochter', 0.597574770450592),
#  ('Advokat', 0.5965981483459473),
#  ('Weerth', 0.5941691398620605),
#  ('Gagern', 0.5936335921287537),
#  ('Aristokrat', 0.5928776264190674),
#  ('Schimmelpfennig', 0.5920757055282593),
#  ('Demokrat', 0.5877822041511536),
#  ('Student', 0.5867450833320618),
#  ('Cabet', 0.5863481163978577),
#  ('Sasonow', 0.5862720608711243),
#  ('Haller', 0.5827111005783081),
#  ('älteste', 0.5825262069702148),
#  ('Howell', 0.5817673206329346),
#  ('stoische', 0.5815796256065369),
#  ('Inspektor', 0.5808447599411011),
#  ('Paléologue', 0.5802479386329651),
#  ('ehrwürdige', 0.58016037940979),
#  ('Thomas', 0.57985919713974),
#  ('Odilon', 0.5797971487045288),
#  ('Dudley', 0.5792602300643921),
#  ('Lincoln', 0.5789412260055542),
#  ('Yorke', 0.5784074664115906),
#  ('Maria', 0.5771102905273438),
#  ('Pfaffe', 0.5769452452659607),
#  ('Jean', 0.5765843391418457),
#  ('Blenker', 0.5765454173088074),
#  ('Netschajew', 0.5758488774299622),
#  ('Jungfrau', 0.57529616355896),
#  ('Reichenbach', 0.5752747058868408),
#  ('Friedensgesellschaft', 0.5750494003295898),
#  ('Humphrey', 0.5750480890274048),
#  ('Cambon', 0.5746475458145142),
#  ('Shaftesbury', 0.5739035606384277),
#  ('Sidney', 0.5738122463226318),
#  ('Urquhart', 0.5737548470497131),
#  ('Konservativer', 0.572451114654541),
#  ('Samuel', 0.5723336935043335),
#  ('Lump', 0.5720323324203491),
#  ('Richardson', 0.570704460144043),
#  ('Parteigenosse', 0.5700960159301758),
#  ('pikante', 0.5700027942657471),
#  ('Journalist', 0.5692251920700073),
#  ('ehemaliger', 0.568475604057312),
#  ('Comte', 0.5684270262718201),
#  ('Gustav', 0.5682985782623291),
#  ('Adolf', 0.5676270127296448),
#  ('Russki', 0.567332923412323),
#  ('Senior', 0.5667616128921509),
#  ('Ernest', 0.5664025545120239),
#  ('Harris', 0.565255880355835),
#  ('Opportunist', 0.5651882886886597),
#  ('Kommandant', 0.56488037109375),
#  ('Brown', 0.5642052888870239),
#  ('Zimmermann', 0.5641510486602783),
#  ('Anarchist', 0.5639994144439697),
#  ('Reuter', 0.563558042049408),
#  ('Hall', 0.5633563995361328),
#  ('Loyd', 0.5628736019134521),
#  ('Schatzmeister', 0.5628362894058228),
#  ('angesehener', 0.5627653002738953),
#  ('Fox', 0.5626565217971802),
#  ('Parlamentsmitglied', 0.561892032623291),
#  ('wackere', 0.5618065595626831),
#  ('Edgar', 0.5617548227310181),
#  ('Pastor', 0.5614580512046814),
#  ('Publizist', 0.561456024646759),
#  ('gottesfürchtige', 0.5608157515525818),
#  ('Simon', 0.5602602362632751),
#  ('Locke', 0.5602061748504639),
#  ('Zetkin', 0.5596626996994019),
#  ('gelehrte', 0.5595988631248474),
#  ('Drigalski', 0.5583869218826294),
#  ('Burnes', 0.5583515763282776),
#  ('Alexandrowna', 0.5581654906272888),
#  ('Gräfin', 0.5577081441879272),
#  ('Bublikow', 0.5574743747711182),
#  ('Techow', 0.5573744773864746),
#  ('Christ', 0.5571892261505127),
#  ('Taylor', 0.5569892525672913),
#  ('Propagandist', 0.5569868087768555),
#  ('Hugo', 0.5569801330566406),
#  ('Wise', 0.5569781064987183),
#  ('Garnier-Pagès', 0.5567776560783386),
#  ('Schaible', 0.5566117763519287),
#  ('Panmure', 0.5564060807228088),
#  ('Gambuzzi', 0.5562161207199097),
#  ('More', 0.5560238361358643),
#  ('Gorki', 0.5559460520744324),
#  ('Admiralität', 0.5559095144271851),
#  ('Dame', 0.5556259155273438),
#  ('Abgeordneter', 0.5555663108825684)]

# %%
# build models for single author's texts
print("me")
model_me = Word2Vec(me_prepared, size=300)
print("trotzki")
model_trotzki = Word2Vec(trotzki_prepared, size=300)
print("stalin")
model_stalin = Word2Vec(stalin_prepared, size=300)
print("amazon")
model_amazon = Word2Vec(amazon_prepared, size=300)
# Out:
# me
# trotzki
# stalin
# amazon
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e107d2d0f55b> in <module>()
#       7 model_stalin = Word2Vec(stalin_prepared, size=300)
#       8 print("amazon")
# ----> 9 model_amazon = Word2Vec(amazon_prepared, size=300)
#
# NameError: name 'amazon_prepared' is not defined

# %%
model_me.wv.most_similar(positive=["König", "Frau"], negative=["Mann"], topn=100)
# Out:
# [('Minister', 0.6884921789169312),
#  ('Königin', 0.68683260679245),
#  ('Palmerston', 0.678479790687561),
#  ('Lord', 0.6620101928710938),
#  ('Bakunin', 0.6577446460723877),
#  ('Russell', 0.6527258157730103),
#  ('Mazzini', 0.6345995664596558),
#  ('Cherval', 0.627071738243103),
#  ('Kaiser', 0.6219127178192139),
#  ('Bonaparte', 0.6214568614959717),
#  ('Graf', 0.6192086338996887),
#  ('Aberdeen', 0.6159704327583313),
#  ('Nikolaus', 0.6157687306404114),
#  ('Kossuth', 0.6048221588134766),
#  ('Tochter', 0.6007236838340759),
#  ('öffentlich', 0.6005090475082397),
#  ('Adresse', 0.6002217531204224),
#  ('Thiers', 0.5997283458709717),
#  ('Majestät', 0.5966911315917969),
#  ('Clarendon', 0.5955820083618164),
#  ('Botschafter', 0.5912646651268005),
#  ('Joseph', 0.5890506505966187),
#  ('Grafen', 0.5883824825286865),
#  ('Botschaft', 0.586836576461792),
#  ('John', 0.5854923725128174),
#  ('Mutter', 0.5848037004470825),
#  ('Viscount', 0.5845451354980469),
#  ('Versammlung', 0.5794788599014282),
#  ('Herrn', 0.5790050029754639),
#  ('Bismarck', 0.5784822106361389),
#  ('Resignation', 0.5781328678131104),
#  ('Peel', 0.5779441595077515),
#  ('Korrespondenz', 0.5771058797836304),
#  ('Perrier', 0.5740618109703064),
#  ('Wellington', 0.5728645324707031),
#  ('Erklärung', 0.5725955963134766),
#  ('Barrot', 0.5722448825836182),
#  ('Herzog', 0.5710127353668213),
#  ('Louis', 0.5708702802658081),
#  ('Nationalversammlung', 0.5669288635253906),
#  ('Newcastle', 0.5665791630744934),
#  ('Lords', 0.5647760629653931),
#  ('Admiral', 0.5640872716903687),
#  ('Gesandtschaft', 0.5636600255966187),
#  ('Fleury', 0.5634075403213501),
#  ('Depesche', 0.5614122748374939),
#  ('Kollegen', 0.5610377788543701),
#  ('Seele', 0.5607389807701111),
#  ('Freunde', 0.5604112148284912),
#  ('Kriegsminister', 0.5593931674957275),
#  ('Konsul', 0.5590388178825378),
#  ('Bürger', 0.5589907765388489),
#  ('Franz', 0.5587633848190308),
#  ('Jules', 0.5572278499603271),
#  ('Rede', 0.5571736097335815),
#  ('Papst', 0.5559945106506348),
#  ('Zar', 0.5541359186172485),
#  ('Proklamation', 0.5514619946479797),
#  ('erklärte', 0.5513851642608643),
#  ('Nachfolger', 0.5511744022369385),
#  ('Ruge', 0.5511296987533569),
#  ('Stieber', 0.5508646965026855),
#  ('Netschajew', 0.5501561760902405),
#  ('Herr', 0.5494362115859985),
#  ('Fazy', 0.5474379062652588),
#  ('Hof', 0.5465239882469177),
#  ('Redcliffe', 0.5459139347076416),
#  ('Bebel', 0.5454121828079224),
#  ('Angeklagten', 0.5452368259429932),
#  ('Schrift', 0.5451033115386963),
#  ('Madame', 0.544754683971405),
#  ('Freund', 0.544187605381012),
#  ('Bonapartes', 0.5420442819595337),
#  ('Konsorten', 0.5413156151771545),
#  ('Unterredung', 0.5412466526031494),
#  ('Motion', 0.5400617122650146),
#  ('Alexander', 0.5400298833847046),
#  ('Legende', 0.5382527112960815),
#  ('Heß', 0.537702739238739),
#  ('Fould', 0.5376095771789551),
#  ('Instruktionen', 0.5374751091003418),
#  ('Gesandten', 0.5369633436203003),
#  ('Mission', 0.5367714762687683),
#  ('Graham', 0.5357762575149536),
#  ('Camphausen', 0.5357251763343811),
#  ('Kabinett', 0.5356062650680542),
#  ('Anklage', 0.5347352623939514),
#  ('Hoheit', 0.5329097509384155),
#  ('Kölner', 0.5324792861938477),
#  ('Arnold', 0.5323895215988159),
#  ('Richter', 0.5313903093338013),
#  ('Lordschaft', 0.5310549736022949),
#  ('James', 0.5307565927505493),
#  ('Ansprache', 0.5294874906539917),
#  ('Sue', 0.5294662714004517),
#  ('Baron', 0.5293477177619934),
#  ('Liebknecht', 0.5287275314331055),
#  ('Briefe', 0.5286338329315186),
#  ('Odilon', 0.5284435153007507),
#  ('Gräfin', 0.528423547744751)]

# %%
# get lists of similar words for single author's texts
word = "Wert"
n = 1000

sim_me = model_me.wv.similar_by_vector(word, topn=n)
print(sim_me)
sim_me = {elem[0]:i+1 for i, elem in enumerate(sim_me)}

sim_t = model_trotzki.wv.similar_by_vector(word, topn=n)
print(sim_t)
sim_t = {elem[0]:i+1 for i, elem in enumerate(sim_t)}

sim_s = model_stalin.wv.similar_by_vector(word, topn=n)
print(sim_s)
sim_s = {elem[0]:i+1 for i, elem in enumerate(sim_s)}
# Out:
# [('Preis', 0.8866859674453735), ('Tauschwert', 0.8232219219207764), ('Produktionspreis', 0.8092413544654846), ('Mehrwert', 0.8063518404960632), ('Gebrauchswert', 0.8039302825927734), ('Marktpreis', 0.7886070013046265), ('Arbeitslohn', 0.7742884159088135), ('Kostpreis', 0.7637040615081787), ('Kapitalwert', 0.734419584274292), ('Wertteil', 0.7223323583602905), ('Betrag', 0.7158682942390442), ('Werte', 0.7148949503898621), ('Profit', 0.7094001770019531), ('Warenwert', 0.7041404843330383), ('Ware', 0.7041052579879761), ('Lohn', 0.7035674452781677), ('Wertgröße', 0.6968942284584045), ('Waren', 0.6953948140144348), ('Wertausdruck', 0.6937711834907532), ('Arbeitstag', 0.6927989721298218), ('Überschuß', 0.6924458742141724), ('Produkt', 0.6904069185256958), ('Arbeitskraft', 0.6857573986053467), ('Verkauf', 0.6818612813949585), ('Gesamtwert', 0.6809176206588745), ('Wechsel', 0.6739211678504944), ('Ertrag', 0.6692504286766052), ('Kapitalteil', 0.6664535403251648), ('Mehrarbeit', 0.6632927656173706), ('Käufer', 0.66133713722229), ('Marktwert', 0.6591466665267944), ('Durchschnittsprofit', 0.6586378216743469), ('Austausch', 0.6580262184143066), ('Geldwert', 0.6500676870346069), ('Umfang', 0.648368239402771), ('Rock', 0.6479694247245789), ('Eigner', 0.6475235223770142), ('
Entschluss', 0.7774548530578613), ('minimalen', 0.7774539589881897), ('Kapitalist', 0.7763608694076538), ('Atombomben', 0.7763375043869019), ('Besorgnis', 0.7757612466812134), ('Elan', 0.7756159901618958), ('Summen', 0.7746219038963318), ('Pferd', 0.774331271648407), ('Ausfall', 0.7738267183303833), ('Armeestab', 0.7735812664031982), ('Berechtigung', 0.7735582590103149), ('lossagen', 0.7734401226043701), ('Illusionen', 0.7731645107269287), ('Jargons', 0.7730193734169006), ('Abänderungsantrag', 0.7729008197784424), ('herausgekommen', 0.7727980613708496), ('Erhebung', 0.7723482847213745), ('Spion', 0.7722060084342957), ('Grüppchen', 0.7722002267837524), ('Aggressoren', 0.7719442844390869), ('Drohungen', 0.7718559503555298), ('Abmachung', 0.771696150302887), ('Murren', 0.7715720534324646), ('herzliche', 0.7715119123458862), ('seinerseits', 0.7714551091194153), ('streng', 0.7711838483810425), ('restlichen', 0.7711089849472046), ('abgewandt', 0.7707217335700989), ('schlechten', 0.7706564664840698), ('Import', 0.7696601152420044), ('bedeutsamen', 0.7691240310668945), ('Weichsel', 0.7690538167953491), ('Abreise', 0.7687150835990906), ('Erinnerungen', 0.7685720920562744), ('Profit', 0.7681484222412109), ('Grenze', 0.768048882484436), ('Intellektueller', 0.767844557762146), ('Sumpf', 0.7678022384643555), ('Streitigkeiten', 0.7673147916793823), ('Deut', 0.767305850982666), ('Gerümpel', 0.7670810222625732), ('Folgen', 0.7667024731636047), ('SZV', 0.7664092183113098), ('Übelstand', 0.7661458253860474), ('entlassen', 0.7660686373710632), ('gewährt', 0.7657753229141235), ('geeinigt', 0.7656904458999634), ('Großmächten', 0.765583336353302), ('Eifer', 0.7652754783630371), ('Arbeitslohn', 0.7650089859962463), ('Zeugnis', 0.76481693983078), ('Ozean', 0.7646210789680481), ('Eroberungskrieg', 0.7646149396896362), ('Arbeitskraft', 0.7646034955978394), ('Peter', 0.7641635537147522), ('Konfusion', 0.763869047164917), ('Illusion', 0.7638482451438904), ('Überholung', 0.7634660005569458), ('langwierigen', 0.7633380889892578), ('Überbleibsel', 0.7632464170455933), ('Deputierte', 0.7631038427352905), ('Evakuierung', 0.7630388736724854), ('Eisenhüttenindustrie', 0.76270592212677), ('Gegenschlag', 0.7624664306640625), ('Legalität', 0.7622917890548706 ...

# %%
def compare_lists(l1, l2):
    d1 = {elem[0]: i+1 for i, elem in enumerate(l1)}
    d2 = {elem[0]: i+1 for i, elem in enumerate(l2)}
    s1 = set(d1)
    s2 = set(d2)

    res = 0
    for elem in s1.intersection(s2):
        res += (len(l1) - abs(d1[elem] - d2[elem])) / len(l1)**2
    return res

# %%
# print similarities between single authors
print("Trotzki:", compare_lists(sim_me, sim_t))
print("Stalin: ", compare_lists(sim_me, sim_s))
print("T-S   : ", compare_lists(sim_s, sim_t))
# Out:
# Trotzki: 0.04098400000000001
# Stalin:  0.044620999999999994
# T-S   :  0.04550499999999999
